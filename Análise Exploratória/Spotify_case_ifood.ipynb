# %% [markdown]
# Data Reporting - Storytelling Case
#
# # Análise de dados do Spotify
#
# Neste notebook apresentarei a análise exploratória dos meus dados no Spotify. O objetivo desse projeto é analisar quais tipo de músicas,artistas, gêneros e quantidades de horas escutadas.
# Para complemento dos dados foi usado a API do Spotify.
#
# ---
# 1 - A estrutura da análise está da seguinte forma:
#
# - Carregamento dos dados
# - Tratamento dos dados
# - Carregamento dos dados para a requisição da API
# - Consumo de API
# - Exploração dos dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests 
plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### Carregamento dos dados

# %%
data_spotify = pd.read_json('/content/drive/MyDrive/Spotify/StreamingHistory0.json')

# %%
data_spotify
# Out:
#                endTime        artistName                 trackName  msPlayed
# 0     2020-12-03 03:47          Ian Wong       Voices from the Sky    169447
# 1     2020-12-03 03:49    Limelight Glow  Sunshine - Cello Version    132162
# 2     2020-12-03 03:52             LUCHS        Red Gold Yesterday    138440
# 3     2020-12-03 03:54          Ian Wong             Winter Dreams    146428
# 4     2020-12-03 03:57  Slow Rising Hope                  Momentum    153667
# ...                ...               ...                       ...       ...
# 1140  2021-07-15 16:51               KLB          A Dor Desse Amor    185278
# 1141  2021-07-15 16:55        Katy Perry                  Firework    227882
# 1142  2021-07-15 17:00     Nelly Furtado               Promiscuous    242278
# 1143  2021-07-16 15:15        Bruno Mars                 24K Magic    225978
# 1144  2021-07-16 15:18        Bruno Mars      Just the Way You Are    153611
#
# [1145 rows x 4 columns]

# %% [markdown]
# ### Tratamento dos dados

# %%
data_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   endTime     1145 non-null   object
#  1   artistName  1145 non-null   object
#  2   trackName   1145 non-null   object
#  3   msPlayed    1145 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 35.9+ KB

# %%
import pytz

# %%
#mudando o tipo da endTime
data_spotify['endTime']  = pd.to_datetime(data_spotify['endTime'],utc=True)

# %%
#Passando para o UTC local
brasil_timezone = pytz.timezone('Brazil/East')
data_spotify['endTime'] = data_spotify['endTime'].dt.tz_convert(brasil_timezone)

# %%
# Acrescentando mais algumas colunas no dataset a partir da endtime
data_spotify['ano'] = data_spotify['endTime'].dt.year
data_spotify['mes'] = data_spotify['endTime'].dt.month
data_spotify['dia'] = data_spotify['endTime'].dt.day
data_spotify['diaSemana'] = data_spotify['endTime'].dt.weekday
data_spotify['tempo'] = data_spotify['endTime'].dt.time
data_spotify['horas'] = data_spotify['endTime'].dt.hour
data_spotify['nomeDia'] = data_spotify['endTime'].map( lambda x: x.day_name())

# %%
# Acrescentando coluna de duração em Horas e em minutos 
data_spotify['tempoEscutado(h)'] = data_spotify['msPlayed'].map(lambda x: x/(3600000) ).round(4)
data_spotify['tempoEscutado(min)'] = data_spotify['msPlayed'].map(lambda x: x/60000).round(4)

# %%
data_spotify.head()
# Out:
#                     endTime  ... tempoEscutado(min)
# 0 2020-12-03 01:47:00-02:00  ...             2.8241
# 1 2020-12-03 01:49:00-02:00  ...             2.2027
# 2 2020-12-03 01:52:00-02:00  ...             2.3073
# 3 2020-12-03 01:54:00-02:00  ...             2.4405
# 4 2020-12-03 01:57:00-02:00  ...             2.5611
#
# [5 rows x 13 columns]

# %%
data_spotify.drop(columns=['diaSemana'],inplace=True)
data_spotify.rename(columns={'nomeDia':'diaSemana'},inplace=True)

# %%
data_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   endTime             1145 non-null   datetime64[ns, Brazil/East]
#  1   artistName          1145 non-null   object
#  2   trackName           1145 non-null   object
#  3   msPlayed            1145 non-null   int64
#  4   ano                 1145 non-null   int64
#  5   mes                 1145 non-null   int64
#  6   dia                 1145 non-null   int64
#  7   tempo               1145 non-null   object
#  8   horas               1145 non-null   int64
#  9   diaSemana           1145 non-null   object
#  10  tempoEscutado(h)    1145 non-null   float64
#  11  tempoEscutado(min)  1145 non-null   float64
# dtypes: datetime64[ns, Brazil/East](1), float64(2), int64(5), object(4)
# memory usage: 107.5+ KB

# %%
data_spotify.describe()
# Out:
#            msPlayed          ano  ...  tempoEscutado(h)  tempoEscutado(min)
# count  1.145000e+03  1145.000000  ...       1145.000000         1145.000000
# mean   2.116413e+05  2020.868122  ...          0.058788            3.527358
# std    1.665635e+05     0.338506  ...          0.046269            2.776058
# min    0.000000e+00  2020.000000  ...          0.000000            0.000000
# 25%    1.476800e+05  2021.000000  ...          0.041000            2.461300
# 50%    2.078200e+05  2021.000000  ...          0.057700            3.463700
# 75%    2.610400e+05  2021.000000  ...          0.072500            4.350700
# max    3.149195e+06  2021.000000  ...          0.874800           52.486600
#
# [8 rows x 7 columns]

# %%
# dropando os podcast
df_f = data_spotify.loc[(data_spotify['artistName'] == 'Tenho Dado Podcast') | (data_spotify['artistName'] == 'Data Hackers')]
data_spotify = data_spotify.drop(df_f.index)

# %%
# quantidade unicas de artistasName 
len(data_spotify['artistName'].unique().tolist())
# Out:
# 440

# %%
# qtd unicas de trackName
len(data_spotify['trackName'].unique().tolist())
# Out:
# 757

# %%
data_spotify
# Out:
#                        endTime  ... tempoEscutado(min)
# 0    2020-12-03 01:47:00-02:00  ...             2.8241
# 1    2020-12-03 01:49:00-02:00  ...             2.2027
# 2    2020-12-03 01:52:00-02:00  ...             2.3073
# 3    2020-12-03 01:54:00-02:00  ...             2.4405
# 4    2020-12-03 01:57:00-02:00  ...             2.5611
# ...                        ...  ...                ...
# 1140 2021-07-15 13:51:00-03:00  ...             3.0880
# 1141 2021-07-15 13:55:00-03:00  ...             3.7980
# 1142 2021-07-15 14:00:00-03:00  ...             4.0380
# 1143 2021-07-16 12:15:00-03:00  ...             3.7663
# 1144 2021-07-16 12:18:00-03:00  ...             2.5602
#
# [1141 rows x 12 columns]

# %% [markdown]
# ### **Dados dos ids de artista  e musicas**
#
# ### Para conseguir fazer as requisições, foi necessário conseguir os id's de cada artista. Para isso, foi necessário uma procura no Kaggle. Os dados que com id's foram esses: https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks?select=artists.csv

# %%
# Carregamento do csv com id's de artistas
data_ids = pd.read_csv('/content/drive/MyDrive/Spotify/artists.csv')

# %%
# Carregamento dos dados com id's de música
data_music_ids = pd.read_csv('/content/drive/MyDrive/Spotify/tracks.csv')

# %%
#Tratando os dados dos artistas. Dropando algumas colunas.
data_ids.drop(columns=['followers','genres','popularity'],inplace=True)

# %%
data_ids.head()
# Out:
#                        id                                            name
# 0  0DheY5irMjBUeLybbCUEZ2  Armid & Amir Zare Pashai feat. Sara Rouzbehani
# 1  0DlhY15l3wsrnlfGio2bjU                                     ปูนา ภาวิณี
# 2  0DmRESX2JknGPQyO15yxg7                                           Sadaa
# 3  0DmhnbHjm1qw6NCYPeZNgJ                                       Tra'gruda
# 4  0Dn11fWM7vHQ3rinvWEl4E                          Ioannis Panoutsopoulos

# %%
data_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   id      1104349 non-null  object
#  1   name    1104349 non-null  object
# dtypes: object(2)
# memory usage: 16.9+ MB

# %%
data_novo = {
    'id': [],
    'nome': []
}

# %%
#verificando os artistas que possuem no dataset original
artistas = set(data_spotify['artistName'].tolist())
artistas = list(artistas)
len(artistas)
# Out:
# 440

# %%
# Comparando os artistas do dataset(df) original com o dataset com os ids.
for i in artistas:
  for name,id in zip(data_ids.name, data_ids['id']):
    if i == name:
        data_novo['nome'].append(name)
        data_novo['id'].append(id)
    else:
      continue

# %%
# convertendo o dicionario para um dataframe
data_novo = pd.DataFrame(data_novo)
data_novo
# Out:
#                          id              nome
# 0    4iHNK0tOyZPYnBU7nGAgpQ      Mariah Carey
# 1    0IVBT8qQNwvHLzOJL6kGpE           Oriente
# 2    0UbJJayomun8CvZKCPH9j3  Luíza & Maurílio
# 3    0RPzmE1iY76tx1eBBXFyYn           DJ Ivis
# 4    601893mmW5hl1FBOykWZHG       Deborah Cox
# ..                      ...               ...
# 442  6iAY2AyUZLSX3PWLIAfFZY       Fernandinho
# 443  5QQUuUIP9gjrkI8amLfIlb    André e Felipe
# 444  69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 445  76DjxkWnHza9Q02cejvQhc           Agostta
# 446  2aUEJRWyEuYRQD3OiR69Qz          MC Kinho
#
# [447 rows x 2 columns]

# %%
# Começando as analises de musicas. Foi necessario dar uma limpeza na coluna artista
lista = []
data_music_ids[['id','name','artists']]
m = data_music_ids['artists'].tolist()
for i in range(len(m)):
  lista.append(m[i].replace("[","").replace("'","").replace("]",""))
data_music_ids['artists'] = lista
data_music_ids
# Out:
#                             id  ... time_signature
# 0       35iwgR4jXetI318WEWsa1Q  ...              3
# 1       021ht4sdgPcrDgSk7JTbKY  ...              1
# 2       07A5yehtSnoedViJAZkNnc  ...              5
# 3       08FmqUhxtyLTn6pAh6bk45  ...              3
# 4       08y9GfoqCWfOGsKdwojr5e  ...              4
# ...                        ...  ...            ...
# 586667  5rgu12WBIHQtvej2MdHSH0  ...              4
# 586668  0NuWgxEp51CutD2pJoF4OM  ...              4
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  ...              4
# 586670  45XJsGpFTyzbzeWK8VzR8S  ...              4
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn  ...              4
#
# [586672 rows x 20 columns]

# %%
data_music_novo = {
    'id': [],
     'trackName': [],
     'artistName': []
}

# %%
data_musicas = data_spotify[['trackName','artistName']]
data_musicas
# Out:
#                      trackName        artistName
# 0          Voices from the Sky          Ian Wong
# 1     Sunshine - Cello Version    Limelight Glow
# 2           Red Gold Yesterday             LUCHS
# 3                Winter Dreams          Ian Wong
# 4                     Momentum  Slow Rising Hope
# ...                        ...               ...
# 1140          A Dor Desse Amor               KLB
# 1141                  Firework        Katy Perry
# 1142               Promiscuous     Nelly Furtado
# 1143                 24K Magic        Bruno Mars
# 1144      Just the Way You Are        Bruno Mars
#
# [1141 rows x 2 columns]

# %%
for trackName,artistName in zip(data_musicas.trackName,data_musicas.artistName) :
  for name,id,artists in zip(data_music_ids.name, data_music_ids['id'],data_music_ids['artists']):
    if trackName == name and artistName == artists :
        data_music_novo['id'].append(id)
        data_music_novo['trackName'].append(name)
        data_music_novo['artistName'].append(artists)
    else:
      continue

# %% [markdown]
# Como podemos ver, não poderemos trabalhar com os id's de músicas, pois algumas músicas tem mais que um. Isso se deve as músicas com participações especiais ou gravadas com uma roupagem nova.

# %%
data_music_novo = pd.DataFrame(data_music_novo)
data_music_novo
# Out:
#                          id              trackName         artistName
# 0    5aVnC5HP5LtiGsx6OUyfUr  My Heart Belongs To U             Jodeci
# 1    6xzbFFuCMO6xUZK9b0eO8k      Deus de Promessas     Toque no Altar
# 2    1zw6Xhftd6MUSYPhcEUw1T           Olha pra Mim     Toque no Altar
# 3    1uub1a10rYv75hImhcaUGx      Milagre - Ao Vivo      André Valadão
# 4    2htH5qQj7CihxAUifwvvWi       Aclame Ao Senhor  Ana Paula Valadão
# ..                      ...                    ...                ...
# 771  7Ica2aGF93g9UkxcqaarOs   Just the Way You Are         Bruno Mars
# 772  47Slg6LuqLaX0VodpSCvPt   Just the Way You Are         Bruno Mars
# 773  7BqBn9nzAq8spo5e7cZ0dJ   Just the Way You Are         Bruno Mars
# 774  2XPkrmtbHBP9d268Rrlogy   Just the Way You Are         Bruno Mars
# 775  0glMVboHnPISsYHEOCUKWN   Just the Way You Are         Bruno Mars
#
# [776 rows x 3 columns]

# %% [markdown]
# ## Usando a API do Spotify
# ### Para auxilio na construção da análise, usarei a API para conseguir mais dados como gênero e popularidade dos artistas.

# %%
# Para se conseguir acesso a API é necessário o cadastro no Developer Spotify, onde conseguirá as credenciais. 

#Credenciais para acesso
CLIENT_ID = #Seu Id client
CLIENT_SECRET = #sua secret client


AUTH_URL = 'https://accounts.spotify.com/api/token'

#Post
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

auth_response_data = auth_response.json()

access_token = auth_response_data['access_token']

headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
#URL BASE
BASE_URL = 'https://api.spotify.com/v1/'

# %% [markdown]
# Apesar de não usar os id's das músicas, vamos verificar como são os dados disponibilizados nas requisições de track

# %%
#Verificando os dados requisitados 
#REQUISIÇÃO TRACK
track_id = '35iwgR4jXetI318WEWsa1Q'
r = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers)
r = r.json()
r
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45tIt06XoI0Iio4LBEVpls'},
#     'href': 'https://api.spotify.com/v1/artists/45tIt06XoI0Iio4LBEVpls',
#     'id': '45tIt06XoI0Iio4LBEVpls',
#     'name': 'Uli',
#     'type': 'artist',
#     'uri': 'spotify:artist:45tIt06XoI0Iio4LBEVpls'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4Pmp3enRUgpikOgQS6z2DJ'},
#   'href': 'https://api.spotify.com/v1/albums/4Pmp3enRUgpikOgQS6z2DJ',
#   'id': '4Pmp3enRUgpikOgQS6z2DJ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c856f3487ec0458d3b9cf01d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c856f3487ec0458d3b9cf01d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c856f3487ec0458d3b9cf01d',
#     'width': 64}],
#   'name': 'Carve',
#   'release_date': '1922-02-22',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4Pmp3enRUgpikOgQS6z2DJ'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45tIt06XoI0Iio4LBEVpls'},
#    'href': 'https://api.spotify.com/v1/artists/45tIt06XoI0Iio4LBEVpls',
#    'id': '45tIt06XoI0Iio4LBEVpls',
#    'name': 'Uli',
#    'type': 'artist',
#    'uri': 'spotify:artist:45tIt06XoI0Iio4LBEVpls'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 126902,
#  'explicit': False,
#  'external_ids': {'isrc': 'QZCE61821790'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/35iwgR4jXetI318WEWsa1Q'},
#  'href': 'https://api.spotify.com/v1/tracks/35iwgR4jXetI318WEWsa1Q',
#  'id': '35iwgR4jXetI318WEWsa1Q',
#  'is_local': False,
#  'name': 'Carve',
#  'popularity': 5,
#  'preview_url': 'https://p.scdn.co/mp3-preview/2f41db376b64c4b148cf426ef9a86e16ebcc92d9?cid=6e01f1bf35384a6aa7dfd53bb9f42da0',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:35iwgR4jXetI318WEWsa1Q'}

# %% [markdown]
# Verificando os dados requisitados. Queremos 3 campos: nome, genres e popularity.

# %%
# REQUISIÇÃO ARTISTA
artist_id = '4C7NcNb9V6lakzMGHQlm8i'

r = requests.get(BASE_URL + 'artists/' + artist_id , 
                 headers=headers, 
                 params={'include_groups': 'album', 'limit': 50})
d = r.json()
d
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4C7NcNb9V6lakzMGHQlm8i'},
#  'followers': {'href': None, 'total': 8759},
#  'genres': ['lo-fi beats', 'lo-fi jazzhop'],
#  'href': 'https://api.spotify.com/v1/artists/4C7NcNb9V6lakzMGHQlm8i',
#  'id': '4C7NcNb9V6lakzMGHQlm8i',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb4dde2ade5db8abff313b8474',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051744dde2ade5db8abff313b8474',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1784dde2ade5db8abff313b8474',
#    'width': 160}],
#  'name': 'Tom Doolie',
#  'popularity': 62,
#  'type': 'artist',
#  'uri': 'spotify:artist:4C7NcNb9V6lakzMGHQlm8i'}

# %%
# Criando um dicionário para inserir nome, gênero e popularidade
data_artista = {
    'nome': [],
    'genero': [],
    'popularidade': []
}

# %%
#Criando uma função para fazer as requisições. Observe que primeiramente add na lista os id que derem erro. 
def info_artista(id):
  r = requests.get(BASE_URL + 'artists/' + id , 
                 headers=headers, 
                 params={'include_groups': 'album', 'limit': 50})
  d = r.json()
  try:
    data_artista['nome'].append(d['name'])
    data_artista['genero'].append(d['genres'])
    data_artista['popularidade'].append(d['popularity'])
  except:
    None
    lista.append(id)

# %%
# Criando a lista vazia para armazenar os ids
lista = []

# %%
# Outra lista para segunda tentativa
lista2 = []

# %%
lista3 = []

# %%
lista4 = []

# %%
# primeira tentativa que é pegando os ids direto do data_novo 
for i in data_novo['id']:
     info_artista(i)

# %%
# Agora na segunda tentariva pegado os ids que deram erro na primeira tentativa
for i in lista:
  info_artista(i)

# %%
# caso precise, terceira tentativa 
for i in lista2:
  info_artista(i)

# %%
# caso precise, quarta tentativa 
for i in lista3:
  info_artista(i)

# %%
# Criando dataframe com nome, gênero e popularidade
data_info_artista = pd.DataFrame(data_artista)
# data_info_artista

# %%
data_art = {
    'nome': [],
    'genero': [],
    'popularidade': []
}

# %%
for i in range(len(data_info_artista)):
  if data_info_artista['nome'][i] not in  data_art['nome']:
    data_art['nome'].append(data_info_artista['nome'][i])
    data_art['genero'].append(data_info_artista['genero'][i])
    data_art['popularidade'].append(data_info_artista['popularidade'][i])
  else:
    continue

# %%
data_art = pd.DataFrame(data_art)
data_art.drop(columns='genero',inplace=True)

# %%
#Popularidade dos cantores da minha lista 
data_info_artista[['nome','popularidade']].sort_values(by='popularidade',ascending=False).head(30)
# Out:
#                nome  popularidade
# 294   Justin Bieber            98
# 233   Ariana Grande            96
# 428      Ed Sheeran            95
# 430        Dua Lipa            95
# 427          Eminem            94
# 130   Billie Eilish            94
# 220      Kanye West            93
# 398      Bruno Mars            93
# 270         Rihanna            92
# 73         Maroon 5            91
# 289     Chris Brown            91
# 121       Lil Wayne            91
# 257   One Direction            90
# 137             Sia            89
# 307       Lady Gaga            89
# 26    Ty Dolla $ign            89
# 18   Kendrick Lamar            89
# 145     Miley Cyrus            88
# 209         Beyoncé            88
# 338         Cardi B            88
# 393      Snoop Dogg            87
# 210      Katy Perry            87
# 432    Jason Derulo            87
# 72          Ava Max            86
# 391          Avicii            86
# 212            Kygo            86
# 340      Little Mix            86
# 385        Big Sean            85
# 371   Gusttavo Lima            85
# 167           Adele            85

# %%
data_info_artista
# Out:
#               nome  ... popularidade
# 0           Áquila  ...           39
# 1             3030  ...           65
# 2    Chloe x Halle  ...           68
# 3           Jon B.  ...           56
# 4       Soulja Boy  ...           74
# ..             ...  ...          ...
# 442           Dudu  ...           63
# 443           Xamã  ...           36
# 444           Xamã  ...           79
# 445           Crod  ...           40
# 446         KALUMA  ...           60
#
# [447 rows x 3 columns]

# %%
# Pegando cada gênero da coluna genero do dataframe
lista_genero = []
genero = data_info_artista['genero'].tolist()
for i in genero:
  for k in range(len(i)):
    lista_genero.append(i[k])

lista_genero
# Out:
# ['brazilian edm',
#  'brazilian hip hop',
#  'trap brasileiro',
#  'alternative r&b',
#  'dance pop',
#  'pop',
#  'pop rap',
#  'post-teen pop',
#  'r&b',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop rap',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'atl hip hop',
#  'chicago bop',
#  'dance pop',
#  'dirty south rap',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'viral rap',
#  'axe',
#  'pagode',
#  'samba paulista',
#  'sertanejo',
#  'sertanejo universitario',
#  'chillhop',
#  'focus beats',
#  'lo-fi beats',
#  'lo-fi jazzhop',
#  'alternative r&b',
#  'chill r&b',
#  'dmv rap',
#  'indie r&b',
#  'indie soul',
#  'neo soul',
#  'pop',
#  'r&b',
#  'urban contemporary',
#  'groove gospel',
#  'adoracao',
#  'brazilian gospel',
#  'world worship',
#  'afrobeat brasileiro',
#  'brazilian hip hop',
#  'brazilian reggae',
#  'brazilian rock',
#  'latin afrobeat',
#  'manguebeat',
#  'conscious hip hop',
#  'hip hop',
#  'rap',
#  'west coast rap',
#  'pop nacional',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'groove gospel',
#  'louvor',
#  'axe',
#  'pagode',
#  'partido alto',
#  'samba',
#  'samba-enredo',
#  'adoracao',
#  'brazilian gospel',
#  'dance pop',
#  'pop',
#  'hip hop',
#  'pop',
#  'pop rap',
#  'r&b',
#  'southern hip hop',
#  'trap',
#  'trap soul',
#  'axe',
#  'pagode',
#  'sertanejo',
#  'sertanejo universitario',
#  'canadian latin',
#  'canadian pop',
#  'dance pop',
#  'pop',
#  'pop rap',
#  'nova mpb',
#  'r&b brasileiro',
#  'funk melody',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'dance pop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop rap',
#  'r&b',
#  'urban contemporary',
#  'bossa nova',
#  'manguebeat',
#  'mpb',
#  'nova mpb',
#  'nova musica pernambucana',
#  'brazilian hip hop',
#  'funk carioca',
#  'r&b brasileiro',
#  'rap baixada fluminense',
#  'rap cristao',
#  'trap cristao',
#  'lo-fi beats',
#  'lo-fi jazzhop',
#  'brazilian hip hop',
#  'conscious hip hop',
#  'hip pop',
#  'neo soul',
#  'new jersey rap',
#  'r&b',
#  'urban contemporary',
#  'brazilian ccm',
#  'funk carioca',
#  'adoracao',
#  'musica crista reformada',
#  'sertanejo pop',
#  'mpb',
#  'nova mpb',
#  'pop nacional',
#  'rap maromba',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'r&b brasileiro',
#  'brazilian hip hop',
#  'funk',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'soul',
#  'urban contemporary',
#  'adoracao',
#  'brazilian gospel',
#  'afrofuturismo brasileiro',
#  'brazilian hip hop',
#  'brazilian rock',
#  'funk ostentacao',
#  'hip hop tuga',
#  'manguebeat',
#  'pop lgbtq+ brasileira',
#  'r&b brasileiro',
#  'boom bap brasileiro',
#  'brazilian hip hop',
#  'funk ostentacao',
#  'sertanejo',
#  'sertanejo universitario',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'dance pop',
#  'pop',
#  'pop',
#  'pop rock',
#  'alt z',
#  'indie electropop',
#  'uk pop',
#  'welsh indie',
#  'adoracao',
#  'dance pop',
#  'neo soul',
#  'pop',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'funk',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'soul',
#  'urban contemporary',
#  'brazilian hip hop',
#  'pop nacional',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop rap',
#  'quiet storm',
#  'r&b',
#  'southern hip hop',
#  'urban contemporary',
#  'r&b brasileiro',
#  'dance pop',
#  'edm',
#  'electropop',
#  'pop',
#  'pop dance',
#  'tropical house',
#  'girl group',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'adoracao',
#  'brazilian gospel',
#  'chillhop',
#  'lo-fi beats',
#  'brazilian gospel',
#  'mpb gospel',
#  'brazilian rock',
#  'r&b brasileiro',
#  'brazilian gospel',
#  'gospel antigas',
#  'pop teen brasileiro',
#  'sertanejo',
#  'sertanejo universitario',
#  'complextro',
#  'edm',
#  'pop dance',
#  'progressive electro house',
#  'pop rap brasileiro',
#  'adoracao',
#  'brazilian gospel',
#  'funk evangelico',
#  'rap cristao',
#  'brazilian hip hop',
#  'pop rap brasileiro',
#  'rap df',
#  'adventista',
#  'louvor',
#  'world worship',
#  'adoracao',
#  'brazilian gospel',
#  'axe',
#  'pagode',
#  'roda de samba',
#  'samba',
#  'samba paulista',
#  'adoracao',
#  'brazilian gospel',
#  'coral gospel',
#  'groove gospel',
#  'afrofuturismo brasileiro',
#  'rap feminino nacional',
#  'brazilian hip hop',
#  'pop rap brasileiro',
#  'trap brasileiro',
#  'adoracao',
#  'brazilian gospel',
#  'axe',
#  'pagode',
#  'brazilian hip hop',
#  'brazilian rock',
#  'pop rap brasileiro',
#  'r&b brasileiro',
#  'scandipop',
#  'eurovision',
#  'adoracao',
#  'adoracao',
#  'brazilian gospel',
#  'rap maromba',
#  'funk carioca',
#  'funk ostentacao',
#  'trap brasileiro',
#  'adoracao',
#  'brazilian gospel',
#  'pagode',
#  'sertanejo',
#  'sertanejo universitario',
#  'funk melody',
#  'brazilian gospel',
#  'gospel antigas',
#  'hip hop',
#  'new orleans rap',
#  'pop rap',
#  'rap',
#  'trap',
#  'boy band',
#  'hip pop',
#  'pop r&b',
#  'pop rap',
#  'r&b',
#  'urban contemporary',
#  'sertanejo pop',
#  'bossa nova',
#  'brazilian boogie',
#  'brazilian soul',
#  'mpb',
#  'samba',
#  'brazilian hip hop',
#  'electropop',
#  'pop',
#  'adoracao',
#  'brazilian gospel',
#  'brazilian gospel',
#  'kingston on indie',
#  'neo-classical',
#  'background music',
#  'background piano',
#  'adoracao',
#  'brazilian gospel',
#  'brazilian gospel',
#  'australian dance',
#  'australian pop',
#  'dance pop',
#  'pop',
#  'detroit hip hop',
#  'gangster rap',
#  'hip hop',
#  'pop rap',
#  'rap',
#  'dutch pop',
#  'dutch rap pop',
#  'adoracao',
#  'brazilian gospel',
#  'groove gospel',
#  'pagode baiano',
#  'pop nacional',
#  'rap cristao',
#  'reggae cristao',
#  'rock gospel brasileiro',
#  'atl hip hop',
#  'dance pop',
#  'hip hop',
#  'pop',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'brazilian gospel',
#  'brazilian gospel',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'adoracao',
#  'brazilian gospel',
#  'chill pop',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop rap',
#  'quiet storm',
#  'r&b',
#  'rap',
#  'urban contemporary',
#  'dance pop',
#  'edm',
#  'pop dance',
#  'tropical house',
#  'uk dance',
#  'funk carioca',
#  'funk ostentacao',
#  'r&b brasileiro',
#  'rap feminino nacional',
#  'adoracao',
#  'brazilian gospel',
#  'adoracao',
#  'brazilian gospel',
#  'louvor',
#  'rock gospel brasileiro',
#  'musica rondoniense',
#  'brazilian reggae',
#  'brazilian rock',
#  'musica juiz-forana',
#  'nova mpb',
#  'pagode',
#  'portuguese pop',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'chillhop',
#  'lo-fi beats',
#  'forro',
#  'axe',
#  'pagode',
#  'british soul',
#  'pop',
#  'pop soul',
#  'uk pop',
#  'pop rap',
#  'brazilian rock',
#  'adoracao',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'afrofuturismo brasileiro',
#  'brazilian hip hop',
#  'trap brasileiro',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'funk carioca',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'adoracao',
#  'brazilian gospel',
#  'r&b brasileiro',
#  'axe',
#  'pagode',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'brazilian hip hop',
#  'rap df',
#  'trap brasileiro',
#  'afrofuturismo brasileiro',
#  'brazilian hip hop',
#  'brazilian reggae',
#  'dance pop',
#  'mpb',
#  'musica popular mineira',
#  'funk carioca',
#  'dance pop',
#  'edm',
#  'electro house',
#  'moombahton',
#  'pop',
#  'pop dance',
#  'pop rap',
#  'jovem guarda',
#  'gangster rap',
#  'hip hop',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'funk 150 bpm',
#  'boy band',
#  'hip pop',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'adoracao',
#  'brazilian gospel',
#  'funk 150 bpm',
#  'funk carioca',
#  'trap funk',
#  'sertanejo gospel',
#  'adoracao',
#  'hip hop',
#  'miami hip hop',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'forro',
#  'forro de favela',
#  'funk carioca',
#  'sertanejo pop',
#  'swedish soul',
#  'funk pop',
#  'musica alagoana',
#  'sertanejo',
#  'sertanejo tradicional',
#  'sertanejo universitario',
#  'funk carioca',
#  'trap funk',
#  'canadian electronic',
#  'edm',
#  'electro house',
#  'pop dance',
#  'progressive house',
#  'pop rap brasileiro',
#  'trap brasileiro',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'r&b',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'adoracao',
#  'brazilian gospel',
#  'edm',
#  'pop',
#  'pop dance',
#  'tropical house',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop r&b',
#  'r&b',
#  'urban contemporary',
#  'brazilian gospel',
#  'gospel antigas',
#  'louvor',
#  'adoracao',
#  'brazilian gospel',
#  'brazilian metal',
#  'brazilian progressive metal',
#  'rock gospel brasileiro',
#  'canadian pop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'vocal house',
#  'adoracao',
#  'brazilian gospel',
#  'gospel antigas',
#  'brazilian emo',
#  'brazilian rock',
#  'pop rock brasileiro',
#  'rock alternativo brasileiro',
#  'adoracao',
#  'chicago rap',
#  'rap',
#  'deep southern trap',
#  'dirty south rap',
#  'gangster rap',
#  'houston rap',
#  'new orleans rap',
#  'southern hip hop',
#  'trap',
#  'brazilian hip hop',
#  'pop rap brasileiro',
#  'r&b brasileiro',
#  'pop',
#  'r&b',
#  'funk melody',
#  'schranz',
#  'boy band',
#  'dance pop',
#  'europop',
#  'sertanejo pop',
#  'dance pop',
#  'girl group',
#  'hip hop',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'adoracao',
#  'brazilian gospel',
#  'funk',
#  'hip hop',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'rap',
#  'urban contemporary',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'forro',
#  'piseiro',
#  'forro',
#  'groove gospel',
#  'axe',
#  'brazilian rock',
#  'funk das antigas',
#  'funk melody',
#  'pagode',
#  'funk',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'soul',
#  'urban contemporary',
#  'alternative r&b',
#  'dance pop',
#  'hip pop',
#  'neo soul',
#  'pop',
#  'pop r&b',
#  'r&b',
#  'urban contemporary',
#  'r&b brasileiro',
#  'sertanejo pop',
#  'dance pop',
#  'edm',
#  'pop',
#  'pop dance',
#  'post-teen pop',
#  'tropical house',
#  'uk pop',
#  'rap baixada fluminense',
#  'trap carioca',
#  'vocaloid',
#  'adoracao',
#  'brazilian gospel',
#  'brazilian gospel',
#  'gospel antigas',
#  'rap maromba',
#  'east coast hip hop',
#  'hip hop',
#  'hip pop',
#  'pop rap',
#  'r&b',
#  'rap',
#  'lo-fi beats',
#  'adoracao',
#  'brazilian gospel',
#  'funk evangelico',
#  'rap cristao',
#  'trap cristao',
#  'brazilian rock',
#  'latin alternative',
#  'manguebeat',
#  'mpb',
#  'pop rock brasileiro',
#  'rock mineiro',
#  'rock nacional brasileiro',
#  'funk paulista',
#  'boy band',
#  'pop',
#  'post-teen pop',
#  'talent show',
#  'dance pop',
#  'deep euro house',
#  'deep house',
#  'edm',
#  'german dance',
#  'pop',
#  'pop dance',
#  'tropical house',
#  'axe',
#  'pagode',
#  'sertanejo',
#  'sertanejo universitario',
#  'adoracao',
#  'brazilian gospel',
#  'adoracao',
#  'gospel',
#  'gospel r&b',
#  'brazilian hip hop',
#  'trap brasileiro',
#  'trap carioca',
#  'axe',
#  'funk das antigas',
#  'funk melody',
#  'pagode',
#  'sertanejo universitario',
#  'brazilian rock',
#  'nova mpb',
#  'pop nacional',
#  'sertanejo pop',
#  'adoracao',
#  'brazilian gospel',
#  'gospel antigas',
#  'indie cristao',
#  'barbadian pop',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'urban contemporary',
#  'groove gospel',
#  'pagode',
#  'sertanejo universitario',
#  'trap brasileiro',
#  'classic romanian pop',
#  'romanian pop',
#  'adoracao',
#  'brazilian gospel',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'alternative r&b',
#  'adoracao',
#  'brazilian gospel',
#  'funk carioca',
#  'brazilian gospel',
#  'gospel antigas',
#  'adoracao',
#  'brazilian gospel',
#  'pop rap',
#  'r&b',
#  'urban contemporary',
#  'alternative r&b',
#  'chill r&b',
#  'indie r&b',
#  'pop r&b',
#  'r&b',
#  'trap soul',
#  'brega funk',
#  'funk carioca',
#  'alternative dance',
#  'norwegian pop',
#  'freestyle',
#  'pagode',
#  'pagode novo',
#  'sertanejo',
#  'sertanejo universitario',
#  'dance pop',
#  'pop',
#  'pop rap',
#  'r&b',
#  'rap',
#  'axe',
#  'pagode',
#  'canadian pop',
#  'pop',
#  'post-teen pop',
#  'louvor',
#  'dance pop',
#  'hip pop',
#  'neo soul',
#  'pop',
#  'pop rap',
#  'r&b',
#  'urban contemporary',
#  'alternative metal',
#  'canadian rock',
#  'nu metal',
#  'post-grunge',
#  'adoracao',
#  'brazilian gospel',
#  'rap maromba',
#  'adoracao',
#  'chillhop',
#  'lo-fi beats',
#  'adoracao',
#  'brazilian gospel',
#  'rock gospel brasileiro',
#  'brazilian gospel',
#  'british black metal',
#  'dance pop',
#  'house',
#  'pop dance',
#  'post-teen pop',
#  'tropical house',
#  'uk dance',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'sertanejo pop',
#  'sertanejo pop',
#  'funk carioca',
#  'pop',
#  'pop lgbtq+ brasileira',
#  'brega funk',
#  'funk carioca',
#  'adoracao',
#  'brazilian gospel',
#  'alternative dance',
#  'big beat',
#  'breakbeat',
#  'electronica',
#  'new rave',
#  'rave',
#  'pagode',
#  'samba paulista',
#  'axe',
#  'pagode',
#  'samba',
#  'atmospheric post-metal',
#  'progressive jazz fusion',
#  'r&b brasileiro',
#  'brazilian gospel',
#  'brazilian hip hop',
#  'funk carioca',
#  'instrumental rock',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'lo-fi beats',
#  'trap brasileiro',
#  'adoracao',
#  'atl hip hop',
#  'dirty south rap',
#  'gangster rap',
#  'hip hop',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'funk',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'sertanejo pop',
#  'funk carioca',
#  'pop lgbtq+ brasileira',
#  'background music',
#  'focus',
#  'brazilian hip hop',
#  'brazilian reggae',
#  'adoracao',
#  'east coast hip hop',
#  'hardcore hip hop',
#  'hip hop',
#  'hip pop',
#  'pop rap',
#  'rap',
#  'dance pop',
#  'pop',
#  'pop rap',
#  'rap',
#  'adoracao',
#  'dance pop',
#  'girl group',
#  'pop',
#  'post-teen pop',
#  'talent show',
#  'uk pop',
#  'adoracao',
#  'brazilian gospel',
#  'gospel antigas',
#  'rap maromba',
#  'dance pop',
#  'hip pop',
#  'pop',
#  'pop r&b',
#  'post-teen pop',
#  'r&b',
#  'urban contemporary',
#  'focus',
#  'focus',
#  'pagode',
#  'pagode novo',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'french indie pop',
#  'french indietronica',
#  'new french touch',
#  'nice indie',
#  'tropical house',
#  'adoracao',
#  'brazilian gospel',
#  'rap baiano',
#  'trap baiano',
#  'trap brasileiro',
#  'pop nacional',
#  'dance pop',
#  'neo soul',
#  'new jack swing',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'instrumental progressive metal',
#  'funk melody',
#  'classic bangla pop',
#  'musique tahitienne',
#  'brega funk',
#  'dance pop',
#  'pop',
#  'r&b',
#  'urban contemporary',
#  'rap nortista',
#  'rap paraense',
#  'sertanejo',
#  'sertanejo universitario',
#  'pagode',
#  'pagode novo',
#  'samba moderno',
#  'rap pernambucano',
#  'brazilian hip hop',
#  'pop rap brasileiro',
#  'adoracao',
#  'brazilian gospel',
#  'adoracao',
#  'brazilian gospel',
#  'brazilian hip hop',
#  'brazilian reggae',
#  'nova mpb',
#  'groove gospel',
#  'louvor',
#  'adoracao',
#  'groove gospel',
#  'rap cristao',
#  'la pop',
#  'forro',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'r&b brasileiro',
#  'rap cearense',
#  'trap brasileiro',
#  'detroit hip hop',
#  'hip hop',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'piseiro',
#  'adoracao',
#  'brazilian gospel',
#  'rock cristiano',
#  'rock gospel brasileiro',
#  'adoracao',
#  'dance pop',
#  'edm',
#  'pop',
#  'pop dance',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'g funk',
#  'gangster rap',
#  'hip hop',
#  'pop rap',
#  'rap',
#  'west coast rap',
#  'boy band',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'adoracao',
#  'brazilian gospel',
#  'dance pop',
#  'pop',
#  'post-teen pop',
#  'pagode',
#  'sertanejo universitario',
#  'hip pop',
#  'neo soul',
#  'new jack swing',
#  'pop r&b',
#  'quiet storm',
#  'r&b',
#  'urban contemporary',
#  'groove gospel',
#  'adoracao',
#  'brazilian gospel',
#  'gospel',
#  'gospel r&b',
#  'smooth jazz',
#  'smooth saxophone',
#  'adoracao',
#  'brazilian gospel',
#  'louvor',
#  'reggae cristao',
#  'funk carioca',
#  'axe',
#  'funk carioca',
#  'funk das antigas',
#  'funk melody',
#  'funk ostentacao',
#  'sertanejo pop',
#  'italian alternative',
#  'italian indie pop',
#  'italian post-hardcore',
#  'rome indie',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'brazilian rock',
#  'nova mpb',
#  'sertanejo',
#  'sertanejo pop',
#  'sertanejo universitario',
#  'musica crista reformada',
#  'battle rap',
#  'hip pop',
#  'philly rap',
#  'pop rap',
#  'rap',
#  'southern hip hop',
#  'trap',
#  'lo-fi beats',
#  'adoracao',
#  'brazilian gospel',
#  'groove gospel',
#  'pop lgbtq+ brasileira',
#  'detroit hip hop',
#  'hip hop',
#  'rap',
#  'pop',
#  'uk pop',
#  'funk das antigas',
#  'dance pop',
#  'pop',
#  'uk pop',
#  'k-rap',
#  'dance pop',
#  'pop',
#  'pop rap',
#  'post-teen pop',
#  'brazilian hip hop',
#  'musica triste brasileira',
#  'pop rap brasileiro',
#  'sertanejo',
#  'sertanejo pop',
#  ...]

# %%
data_genero = {
    'genero':lista_genero
}

# %%
data_genero = pd.DataFrame(data_genero)

# %%
data_genero[data_genero['genero'].str.contains('pop', regex=True, na=True)].head(40)
# Out:
#                     genero
# 4                dance pop
# 5                      pop
# 6                  pop rap
# 7            post-teen pop
# 10                 hip pop
# 13                 pop rap
# 19               dance pop
# 21                 pop rap
# 41                     pop
# 58            pop nacional
# 59           sertanejo pop
# 70               dance pop
# 71                     pop
# 73                     pop
# 74                 pop rap
# 84            canadian pop
# 85               dance pop
# 86                     pop
# 87                 pop rap
# 94               dance pop
# 95                 hip pop
# 98                 pop rap
# 116                hip pop
# 125          sertanejo pop
# 128           pop nacional
# 131          sertanejo pop
# 136                hip pop
# 151  pop lgbtq+ brasileira
# 159          sertanejo pop
# 161              dance pop
# 162                    pop
# 163                    pop
# 164               pop rock
# 166       indie electropop
# 167                 uk pop
# 170              dance pop
# 172                    pop
# 178                hip pop
# 186           pop nacional
# 188                hip pop

# %% [markdown]
# ### Análise exploratória dos dados

# %%
# Top 10 de Artistas que mais ouvi

artista = data_spotify['artistName'].value_counts().head(10)
artista.plot(kind='barh', figsize=(12,6), grid = False, rot=0, color="green")
plt.title('Artistas que mais ouvi - Top 10',size=15)
plt.xlabel('quantidade',size=10)
# Out:
# Text(0.5, 0, 'quantidade')

# %%
# Top 10 das músicas que mais ouvi
musica = data_spotify['trackName'].value_counts().head(10)
musica.plot(kind='barh', figsize=(12,6), grid = False, rot=0, color="green")
plt.title('Musicas que mais ouvi - Top 10',size=15)
plt.xlabel('quantidade',size=10)
# Out:
# Text(0.5, 0, 'quantidade')

# %%
data_spotify = data_spotify.reset_index()
data_spotify.head()
# Out:
#    index                   endTime  ... tempoEscutado(h) tempoEscutado(min)
# 0      0 2020-12-03 01:47:00-02:00  ...           0.0471             2.8241
# 1      1 2020-12-03 01:49:00-02:00  ...           0.0367             2.2027
# 2      2 2020-12-03 01:52:00-02:00  ...           0.0385             2.3073
# 3      3 2020-12-03 01:54:00-02:00  ...           0.0407             2.4405
# 4      4 2020-12-03 01:57:00-02:00  ...           0.0427             2.5611
#
# [5 rows x 13 columns]

# %%
# Quantidade de vezes que a musica tocou separado por artista e musica
musica_artista = data_spotify[['artistName','trackName','index']].groupby(['artistName','trackName'],as_index=False).agg({'index':'count'}).reset_index()
musica_artista.drop(columns=['level_0'],inplace=True)
musica_artista.columns = ['Artista', 'nome da musica', 'qtd tocada']
musica_artista = musica_artista.sort_values(by='qtd tocada',ascending=False).head(10)

sns.barplot(x="qtd tocada", y="nome da musica", data=musica_artista, hue="Artista",palette='Pastel1' )
plt.rcParams["figure.figsize"] = (15,8)
plt.ylabel("")
plt.title("Quantidade de vezes que tocou")
# Out:
# Text(0.5, 1.0, 'Quantidade de vezes que tocou')

# %%
tempo_total = data_spotify['tempoEscutado(h)'].sum()
print(f'Tempo que utilizei o spotify: {tempo_total} horas')
# Out:
# Tempo que utilizei o spotify: 65.4518 horas

# %%
#maiores tempos de musica em minutos 
maiores_tempos_musica = data_spotify[['artistName','trackName','tempoEscutado(min)']].sort_values(by='tempoEscutado(min)',ascending=False)
maiores_tempos_musica = maiores_tempos_musica.drop_duplicates().head(10).reset_index()
maiores_tempos_musica = maiores_tempos_musica.drop(columns='index')
plt.rcParams["figure.figsize"] = (15,8)
sns.barplot(x="tempoEscutado(min)", y="trackName", data=maiores_tempos_musica, hue="artistName",palette='Greens',dodge=False)
plt.xlabel('Minutos',size=15)
plt.ylabel('')
plt.title('Músicas com maiores tempo')
# Out:
# Text(0.5, 1.0, 'Músicas com maiores tempo')

# %%
data_spotify.head()
# Out:
#    index             endTime  ... tempoEscutado(h) tempoEscutado(min)
# 0      0 2020-12-03 03:47:00  ...           0.0471             2.8241
# 1      1 2020-12-03 03:49:00  ...           0.0367             2.2027
# 2      2 2020-12-03 03:52:00  ...           0.0385             2.3073
# 3      3 2020-12-03 03:54:00  ...           0.0407             2.4405
# 4      4 2020-12-03 03:57:00  ...           0.0427             2.5611
#
# [5 rows x 13 columns]

# %%
# Escolhendo o artista que mais escuto, verificar o quanto escutei em minutos por musica
df_BrunoMars = data_spotify.loc[data_spotify['artistName'] == 'Bruno Mars'] 
df_BrunoMars = df_BrunoMars.groupby('trackName').agg({'tempoEscutado(min)': 'sum'}).reset_index().sort_values(by='tempoEscutado(min)',ascending=False).head(10)
plt.rcParams["figure.figsize"] = (15,8)
sns.barplot(x="tempoEscutado(min)", y="trackName", data=df_BrunoMars,palette='Greens_r',dodge=False)
plt.xlabel('Minutos',size=15)
plt.ylabel('')
plt.title("Músicas que mais escutei do Bruno mais em quantidade de tempo",size=15)
# Out:
# Text(0.5, 1.0, 'Músicas que mais escutei do Bruno mais em quantidade de tempo')

# %%
# Tempo total em minutos 
data_spotify['tempoEscutado(min)'].sum()
# Out:
# 3927.172

# %%
#Dias da semana tempo escutado em cada dia
data_spotify.groupby(['diaSemana']).agg({'tempoEscutado(min)':'sum'}).plot(kind='bar',rot=0)
plt.title("Tempo escutado ao longo da semana")
plt.ylabel("min")
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
data_spotify
# Out:
#       index             endTime  ... tempoEscutado(h) tempoEscutado(min)
# 0         0 2020-12-03 03:47:00  ...           0.0471             2.8241
# 1         1 2020-12-03 03:49:00  ...           0.0367             2.2027
# 2         2 2020-12-03 03:52:00  ...           0.0385             2.3073
# 3         3 2020-12-03 03:54:00  ...           0.0407             2.4405
# 4         4 2020-12-03 03:57:00  ...           0.0427             2.5611
# ...     ...                 ...  ...              ...                ...
# 1136   1140 2021-07-15 16:51:00  ...           0.0515             3.0880
# 1137   1141 2021-07-15 16:55:00  ...           0.0633             3.7980
# 1138   1142 2021-07-15 17:00:00  ...           0.0673             4.0380
# 1139   1143 2021-07-16 15:15:00  ...           0.0628             3.7663
# 1140   1144 2021-07-16 15:18:00  ...           0.0427             2.5602
#
# [1141 rows x 13 columns]

# %%
# tempo escutado em minutos ao longo de 2021
datas = data_spotify.groupby(['mes','ano'],as_index=False).agg({'tempoEscutado(min)':'count'}).reset_index().drop(columns='index')
datas = datas.loc[datas['ano'] == 2021]
datas.plot(kind='line',x='mes',y='tempoEscutado(min)')
# datas

# %%
# Gêneros
data_genero = pd.DataFrame(data_genero)
data_genero.value_counts().head(5).plot(kind='bar',rot=45,color='green')

# %%
data_spotify.head()
# Out:
#    index             endTime  ... tempoEscutado(h) tempoEscutado(min)
# 0      0 2020-12-03 03:47:00  ...           0.0471             2.8241
# 1      1 2020-12-03 03:49:00  ...           0.0367             2.2027
# 2      2 2020-12-03 03:52:00  ...           0.0385             2.3073
# 3      3 2020-12-03 03:54:00  ...           0.0407             2.4405
# 4      4 2020-12-03 03:57:00  ...           0.0427             2.5611
#
# [5 rows x 13 columns]

# %%
#Popularidade dos cantores da minha lista top 30
data_info_artista[['nome','popularidade']].sort_values(by='popularidade',ascending=False).head(10)
# Out:
#               nome  popularidade
# 294  Justin Bieber            98
# 233  Ariana Grande            96
# 428     Ed Sheeran            95
# 430       Dua Lipa            95
# 427         Eminem            94
# 130  Billie Eilish            94
# 220     Kanye West            93
# 398     Bruno Mars            93
# 270        Rihanna            92
# 73        Maroon 5            91

# %%
#Cantores que mais escutei em minutos
data_spotify.groupby(['artistName'],as_index=False).agg({'tempoEscutado(min)':'sum'}).sort_values(by='tempoEscutado(min)',ascending=False).reset_index().drop(columns='index')
# Out:
#             artistName  tempoEscutado(min)
# 0           Bruno Mars            502.5871
# 1              Projota            271.3778
# 2              Eyshila            169.8520
# 3    Pineapple StormTv            149.0768
# 4      Diante do Trono             91.8578
# ..                 ...                 ...
# 435            Onze:20              0.0000
# 436       Mateus Asato              0.0000
# 437              Adele              0.0000
# 438              Skank              0.0000
# 439            NX Zero              0.0000
#
# [440 rows x 2 columns]

# %%
#nuvem de palavras das musicas
from wordcloud import WordCloud, STOPWORDS
text = data_spotify.trackName.values
wordcloud = WordCloud(
    width = 3000, #Largura
    height = 2000, #altura
    background_color = 'black',
    contour_width = 2,
    colormap ='Greens',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (10, 20))
plt.imshow(wordcloud, interpolation = 'bilinear') #plotagem da nuvem de palavras
plt.axis('off') #remove as bordas
plt.tight_layout(pad=0)
plt.show()

# %%
import zipfile 
from google.colab import files
data_spotify.to_csv('data_spotify.csv', index = None, header=True) 
files.download('data_spotify.csv')
